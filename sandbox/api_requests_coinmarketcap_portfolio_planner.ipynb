# %%
import os
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
from dotenv import load_dotenv
import json
load_dotenv()
cmc_pro_api_key = os.getenv("CMC_PRO_API_KEY")

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'

parameters = {
  'start':'1',
  # 'limit':'5000',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': cmc_pro_api_key,
}

session = Session()
session.headers.update(headers)

display(type(cmc_pro_api_key))
# Out:
# str

# %%
try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2022-05-11T01:08:35.562Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 5613, 'name': 'nr9gavepxl', 'symbol': 'c2gyyvhoceg', 'slug': 'nu0s26fwbk', 'cmc_rank': 6695, 'num_market_pairs': 5154, 'circulating_supply': 194, 'total_supply': 1972, 'max_supply': 4771, 'last_updated': '2022-05-11T01:08:35.562Z', 'date_added': '2022-05-11T01:08:35.562Z', 'tags': ['38960kg6gz7', 'ww5p2rsnp0h', 'lddnwm1p73n', 'd7ub6gzt8tm', '3rfnj5ipn9u', 'yceh82cd92', 'hqrs0ute84', 'zss4qmbtxyn', 'ais5mum930j', 'ap44q6fcv5j'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.22156444120667662, 'volume_24h': 7429, 'volume_change_24h': 0.8200759102571604, 'percent_change_1h': 0.9024749439372637, 'percent_change_24h': 0.4078377925633436, 'percent_change_7d': 0.3882429506687959, 'market_cap': 0.5290476737505108, 'market_cap_dominance': 8440, 'fully_diluted_market_cap': 0.5039243542049499, 'last_updated': '2022-05-11T01:08:35.562Z'}}}, {'id': 8840, 'name': 'x8yy72vzq6', 'symbol': 'sydp8adzrfq', 'slug': 'od9amfrh3nb', 'cmc_rank': 3750, 'num_market_pairs': 6736, 'circulating_supply': 5335, 'total_supply': 6500, 'max_supply': 5505, 'last_updated': '2022-05-11T01:08:35.562Z', 'date_added': '2022-05-11T01:08:35.562Z', 'tags': ['ywzfxnaxb4', '78zoycpr726', 'sp94cb4amnr', 'gnhcdy03sg', 'ed0t49n47ot', 'jqcqnzpbaf', 'xihacl348c', 'rpbxyidgxa', 'a0c2specpiq', 'v45p8pewkxd'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.41674839744733916, 'volume_24h': 1211, 'volume_change_24h': 0.9614231007574532, 'percent_change_1h': 0.44115967766310726, 'percent_change_24h': 0.08834392597408991, 'percent_change_7d': 0.5254803751444179, 'market_cap': 0.21160228839208273, 'market_cap_dominance': 6032, 'fully_diluted_market_cap': 0.18818946015513038, 'last_updated': '2022-05-11T01:08:35.562Z'}}}, {'id': 9479, 'name': 'jzugfpz7jfk', 'symbol': 'fq5qdweu687', 'slug': 'xxdabmfnev', 'cmc_rank': 5614, 'num_market_pairs': 426, 'circulating_supply': 2889, 'total_supply': 9353, 'max_supply': 1538, 'last_updated': '2022-05-11T01:08:35.562Z', 'date_added': '2022-05-11T01:08:35.562Z', 'tags': ['vwf23xid53g', 'hmpbb393jt', 'mwd7ncjrncr', '84xr6b2bkrs', '8n5c571aig6', 'riv4qayrntj', 'mnx0bnp59q', '5bu22e1j14o', 'oh01tgdoppf', '2mozc48pqes'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.9691243491448325, 'volume_24h': 7347, 'volume_change_24h': 0.8756699134452166, 'percent_change_1h': 0.805561968144537, 'percent_change_24h': 0.4557156985310362, 'percent_change_7d': 0.3392888215812142, 'market_cap': 0.3036966844472928, 'market_cap_dominance': 2621, 'fully_diluted_market_cap': 0.8604978112896797, 'last_updated': '2022-05-11T01:08:35.562Z'}}}, {'id': 2490, 'name': 'm1hhgg5jvn', 'symbol': '41tfhu3ds22', 'slug': 'cng3icxfqed', 'cmc_rank': 6721, 'num_market_pairs': 8093, 'circulating_supply': 5177, 'total_supply': 8351, 'max_supply': 163, 'last_updated': '2022-05-11T01:08:35.562Z', 'date_added': '2022-05-11T01:08:35.562Z', 'tags': ['v74epjkpmeo', 'lvv7wdzn53', '7y54ymxsw9x', '0iv9i7ta5irt', 'jyhekjdz18', '9xe0k9ne1ab', 'pcacm6azid', 'm4qxbe2tsdt', 'or58qdikyrr', 'mxgcwg7rkdk'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'USD': {'price': 0.6866635963142824, 'volume_24h': 2121, 'volume_change_24h': 0.4731294962665942, 'percent_change_1h': 0.3764860849884595, 'percent_change_24h': 0.8773294658872344, 'percent_change_7d': 0.5362619206752866, 'market_cap': 0.32941189292749096, 'market_cap_dominance': 9914, 'fully_diluted_market_cap': 0.9855649870951337, 'last_updated': '2022-05-11T01:08:35.562Z'}}}, {'id': 5381, 'name': '3f38jme0muq', 'symbol': 'osjc2mysl6', 'slug': 'a6age4gpljf', 'cmc_rank': 2071, 'num_market_pairs': 7544, 'circulating_suppl ...

# %%
# Hmmmmm
print(json.dumps(data, indent=3))
# Out:
# {
#    "status": {
#       "timestamp": "2022-05-11T01:08:35.562Z",
#       "error_code": 0,
#       "error_message": null,
#       "elapsed": 1,
#       "credit_count": 1,
#       "notice": null
#    },
#    "data": [
#       {
#          "id": 5613,
#          "name": "nr9gavepxl",
#          "symbol": "c2gyyvhoceg",
#          "slug": "nu0s26fwbk",
#          "cmc_rank": 6695,
#          "num_market_pairs": 5154,
#          "circulating_supply": 194,
#          "total_supply": 1972,
#          "max_supply": 4771,
#          "last_updated": "2022-05-11T01:08:35.562Z",
#          "date_added": "2022-05-11T01:08:35.562Z",
#          "tags": [
#             "38960kg6gz7",
#             "ww5p2rsnp0h",
#             "lddnwm1p73n",
#             "d7ub6gzt8tm",
#             "3rfnj5ipn9u",
#             "yceh82cd92",
#             "hqrs0ute84",
#             "zss4qmbtxyn",
#             "ais5mum930j",
#             "ap44q6fcv5j"
#          ],
#          "platform": null,
#          "self_reported_circulating_supply": null,
#          "self_reported_market_cap": null,
#          "quote": {
#             "USD": {
#                "price": 0.22156444120667662,
#                "volume_24h": 7429,
#                "volume_change_24h": 0.8200759102571604,
#                "percent_change_1h": 0.9024749439372637,
#                "percent_change_24h": 0.4078377925633436,
#                "percent_change_7d": 0.3882429506687959,
#                "market_cap": 0.5290476737505108,
#                "market_cap_dominance": 8440,
#                "fully_diluted_market_cap": 0.5039243542049499,
#                "last_updated": "2022-05-11T01:08:35.562Z"
#             }
#          }
#       },
#       {
#          "id": 8840,
#          "name": "x8yy72vzq6",
#          "symbol": "sydp8adzrfq",
#          "slug": "od9amfrh3nb",
#          "cmc_rank": 3750,
#          "num_market_pairs": 6736,
#          "circulating_supply": 5335,
#          "total_supply": 6500,
#          "max_supply": 5505,
#          "last_updated": "2022-05-11T01:08:35.562Z",
#          "date_added": "2022-05-11T01:08:35.562Z",
#          "tags": [
#             "ywzfxnaxb4",
#             "78zoycpr726",
#             "sp94cb4amnr",
#             "gnhcdy03sg",
#             "ed0t49n47ot",
#             "jqcqnzpbaf",
#             "xihacl348c",
#             "rpbxyidgxa",
#             "a0c2specpiq",
#             "v45p8pewkxd"
#          ],
#          "platform": null,
#          "self_reported_circulating_supply": null,
#          "self_reported_market_cap": null,
#          "quote": {
#             "USD": {
#                "price": 0.41674839744733916,
#                "volume_24h": 1211,
#                "volume_change_24h": 0.9614231007574532,
#                "percent_change_1h": 0.44115967766310726,
#                "percent_change_24h": 0.08834392597408991,
#                "percent_change_7d": 0.5254803751444179,
#                "market_cap": 0.21160228839208273,
#                "market_cap_dominance": 6032,
#                "fully_diluted_market_cap": 0.18818946015513038,
#                "last_updated": "2022-05-11T01:08:35.562Z"
#             }
#          }
#       },
#       {
#          "id": 9479,
#          "name": "jzugfpz7jfk",
#          "symbol": "fq5qdweu687",
#          "slug": "xxdabmfnev",
#          "cmc_rank": 5614,
#          "num_market_pairs": 426,
#          "circulating_supply": 2889,
#          "total_supply": 9353,
#          "max_supply": 1538,
#          "last_updated": "2022-05-11T01:08:35.562Z",
#          "date_added": "2022-05-11T01:08:35.562Z",
#          "tags": [
#             "vwf23xid53g",
#             "hmpbb393jt",
#             "mwd7ncjrncr",
#             "84xr6b2bkrs",
#             "8n5c571aig6",
#             "riv4qayrntj",
#             "mnx0bnp59q",
#             "5bu22e1j14o",
#             "oh01tgdoppf",
#             "2mozc48pqes"
#          ],
#          "platform": null,
#          "self_reported_circulating_supply": null,
#          "self_reported_market_cap": null,
#          "quote": {
#             "USD": {
#                "price": 0.9691243491448325,
#                "volume_24h": 7347,
#                "volume_change_24h": 0.8756699134452166,
#                "percent_change_1h": 0.805561968144537,
#                "percent_change_24h": 0.4557156985310362,
#                "percent_change_7d": 0.3392888215812142,
#                "market_cap": 0.3036966844472928,
#                "market_cap_dominance": 2621,
#                "fully_diluted_market_cap": 0.8604978112896797,
#                "last_updated": "2022-05-11T01:08:35.562Z"
#             }
#          }
#       },
#       {
#          "id": 2490,
#          "name": "m1hhgg5jvn",
#          "symbol": "41tfhu3ds22",
#          "slug": "cng3icxfqed",
#          "cmc_rank": 6721,
#          "num_market_pairs": 8093,
#          "circulating_supply": 5177,
#          "total_supply": 8351,
#          "max_supply": 163,
#          "last_updated": "2022-05-11T01:08:35.562Z",
#          "date_added": "2022-05-11T01:08:35.562Z",
#          "tags": [
#             "v74epjkpmeo",
#             "lvv7wdzn53",
#             "7y54ymxsw9x",
#             "0iv9i7ta5irt",
#             "jyhekjdz18",
#             "9xe0k9ne1ab",
#             "pcacm6azid",
#             "m4qxbe2tsdt",
#             "or58qdikyrr",
#             "mxgcwg7rkdk"
#          ],
#          "platform": null,
#          "self_reported_circulating_supply": null,
#          "self_reported_market_cap": null,
#          "quote": {
#             "USD": {
#                "price": 0.6866635963142824,
#                "volume_24h": 2121,
#                "volume_change_24h": 0.4731294962665942,
#                "percent_change_1h": 0.3764860849884595,
#                "percent_change_24h": 0.8773294658872344,
#                "percent_change_7d": 0.5362619206752866,
#                "market_cap": 0.32941189292749096,
#                "market_cap_dominance": 9914,
#                "fully_diluted_market_cap": 0.9855649870951337,
#                "last_updated": "2022-05-11T01:08:35.562Z"
#             }
#          }
#       },
#       {
#          "id": 5381,
#          "name": "3f38jme0muq",
#          "symbol": "osjc2mysl6",
#          "slug": "a6age4gpljf",
#          "cmc_rank": 2071,
#          "num_market_pairs": 7544,
#          "circulating_supply": 5316,
#          "total_supply": 2184,
#          "max_supply": 947,
#          "last_updated": "2022-05-11T01:08:35.562Z",
#          "date_added": "2022-05-11T01:08:35.562Z",
#          "tags": [
#             "62zybiznx5w",
#             "nbnqve49h6j",
#             "ek36uv4mqrq",
#             "yfbcl232s4",
#             "9uc4wufvnd6",
#             "9flm6xvx85j",
#             "k1u71ecwl8n",
#             "j4ib9m1j9bo",
#             "9d18i7j5c5q",
#             "q0l2bn2tp59"
#          ],
#          "platform": null,
#          "self_reported_circulating_supply": null,
#          "self_reported_market_cap": null,
#          "quote": {
#             "USD": {
#                "price": 0.6074998826213351,
#                "volume_24h": 2898,
#                "volume_change_24h": 0.9118808772688896,
#                "percent_change_1h": 0.48596666716678194,
#                "percent_change_24h": 0.3698839897582842,
#                "percent_change_7d": 0.555925926444161,
#                "market_cap": 0.806289687070536,
#                "market_cap_dominance": 7513,
#                "fully_diluted_market_cap": 0.7075961507504145,
#                "last_updated": "2022-05-11T01:08:35.562Z"
#             }
#          }
#       },
#       {
#          "id": 4948,
#          "name": "vuouc9s6g3h",
#          "symbol": "djwoziagqzl",
#          "slug": "p7k51la60yl",
#          "cmc_rank": 2895,
#          "num_market_pairs": 4851,
#          "circulating_supply": 5001,
#          "total_supply": 3040,
#          "max_supply": 3633,
#          "last_updated": "2022-05-11T01:08:35.562Z",
#          "date_added": "2022-05-11T01:08:35.562Z",
#          "tags": [
#             "hb4gpyetna",
#             "egw6uu767w8",
#             "pyqm2b0hoya",
#             "h1nnbwcgq5l",
#             "wr72wbdttns",
#             "ljana1cyvus",
#             "zq5jx503qvm",
#             "f3bllknb7dr",
#             "0xjc4ydfr34q",
#             "wwpou2xvgp"
#          ],
#          "platform": null,
#          "self_reported_circulating_supply": null,
#          "self_reported_market_cap": null,
#          "quote": {
#             "USD": {
#                "price": 0.7422777799038227,
#                "volume_24h": 5788,
#                "volume_change_24h": 0.7483723860860694,
#                "percent_change_1h": 0.30675570910976235,
#                "percent_change_24h": 0.7827973633389933,
#                "percent_change_7d": 0.7923250553275336,
#                "market_cap": 0.9504030877672305,
#                "market_cap_dominance": 8120,
#                "fully_diluted_market_cap": 0.19660843116338667,
#                "last_updated": "2022-05-11T01:08:35.562Z"
#             }
#          }
#       },
#       {
#          "id": 3780,
#          "name": "wv6ny040lqr",
#          "symbol": "7sefth2p27a",
#          "slug": "lytf8qmjqam",
#          "cmc_rank": 4393,
#          "num_market_pairs": 4411,
#          "circulating_supply": 3364,
#          "total_supply": 3706,
#          "max_supply": 7075,
#          "last_updated": "2022-05-11T01:08:35.562Z",
#          "date_added": "2022-05-11T01:08:35.562Z",
#          "tags": [
#             "icuza47jao",
#             "rrxj0m80bz",
#             "cxbwt5npnin",
#             "00bu7d2igqys6",
#             "jinc1lbnds9",
#             "1cs2lsqwn6v",
#             "lw0pw23wdd",
#             "pjcwolp6w7d",
#             "vvd23bvdjz",
#             "zwuqj6ay4x"
#          ],
#          "platform": null,
#          "self_reported_circulating_supply": null,
#          "self_reported_market_cap": null,
#          "quote": {
#             "USD": {
#                "price": 0.40464156602279555,
#                "volume_24h": 1573,
#                "volume_change_24h": 0.8691260300936343,
#                "percent_change_1h": 0.017092340792690175,
#                "percent_change_24h": 0.398458210806131,
#                "percent_change_7d": 0.643401000104278,
#                "market_cap": 0.2804098750860258,
#                "market_cap_dominance": 2480,
#                "fully_diluted_market_cap": 0.5225998151488873,
#                "last_updated": "2022-05-11T01:08:35.562Z"
#             }
#          }
#       },
#       {
#          "id": 4367,
#          "name": "iixzshwljj",
#          "symbol": "kl0m2b704vk",
#          "slug": "38uy80jjky8",
#          "cmc_rank": 6699,
#          "num_market_pairs": 4994,
#          "circulating_supply": 6015,
#          "total_supply": 6252,
#          "max_supply": 5857,
#          "last_updated": "2022-05-11T01:08:35.562Z",
#          "date_added": "2022-05-11T01:08:35.562Z",
#          "tags": [
#             "yyrs55258sh",
#             "7htwvzbpma",
#             "xwkx077cqfe",
#             "bhert6u59yp",
#             "b16ejwd9zf6",
#             "bnqiln4w4xo",
#             "oc689ke8j4r",
#             "chutwceuzmj",
#             "6b08e3a0k1p",
#             "jqnfdepev5i"
#          ],
#          "platform": null,
#          "self_reported_circulating_supply": null,
#          "self_reported_market_cap": null,
#          "quote": {
#             "USD": {
#                "price": 0.11020442680668374,
#                "volume_24h": 9309,
#                "volume_change_24h": 0.9147795551835622,
#                "percent_change_1h": 0.8194631141204765,
#                "percent_change_24h": 0.2268008002595845,
#                "percent_change_7d": 0.04667352149673931,
#                "market_cap": 0.012203597875749095,
#                "market_cap_dominance": 5822,
#                "fully_diluted_market_cap": 0.5861217976191884,
#                "last_updated": "2022-05-11T01:08:35.562Z"
#             }
#          }
#       },
#       {
#          "id": 1869,
#          "name": "iik2tdxqku",
#          "symbol": "hrlldwhq5m",
#          "slug": "d3tt7kcwaz",
#          "cmc_rank": 7177,
#          "num_market_pairs": 3379,
#          "circulating_supply": 3751,
#          "total_supply": 6056,
#          "max_supply": 5167,
#          "last_updated": "2022-05-11T01:08:35.562Z",
#          "date_added": "2022-05-11T01:08:35.562Z",
#          "tags": [
#             "ffpe6h1gpsg",
#             "rsxnbulnayn",
#             "r26bv0w0hk",
#             "nio8c01yi6",
#             "vm7yh4rip",
#             "d3h4sgpg7ic",
#             "6y68smyr2x2",
#             "264pom0okn4",
#             "o0gnq4vcud8",
#             "948yl8oot3"
#          ],
#          "platform": null,
#          "self_reported_circulating_supply": null,
#          "self_reported_market_cap": null,
#          "quote": {
#             "USD": {
#                "price": 0.12147449937091936,
#                "volume_24h": 8794,
#                "volume_change_24h": 0.3880778091848536,
#                "percent_change_1h": 0.29400489164141375,
#                "percent_change_24h": 0.8292175514461297,
#                "percent_change_7d": 0.5386113035026479,
#                "market_cap": 0.8049693795467192,
#                "market_cap_dominance": 4218,
#                "fully_diluted_market_cap": 0.3290842705587411,
#                "last_updated": "2022-05-11T01:08:35.562Z"
#             }
#          }
#       },
#       {
#          "id": 3456,
#          "name": "sd5anq1f0he",
#          "symbol": "c02t4u2s35",
#          "slug": "74oc4kew3bm",
#          "cmc_rank": 1328,
#          "num_market_pairs": 3108,
#          "circulating_supply": 7029,
#          "total_supply": 3351,
#          "max_supply": 4740,
#          "last_updated": "2022-05-11T01:08:35.562Z",
#          "date_added": "2022-05-11T01:08:35.562Z",
#          "tags": [
#             "ulxo4dnt5m",
#             "uw6blf32fm",
#             "1yotxwf6xp2",
#             "3aujviky6jy",
#             "fpjuz2zl2yo",
#             "fi1ix9xaocs",
#             "c41og7j3m2",
#             "kdraoqndh8a",
#             "p7ucb7n4c6",
#             "gefipuea5bn"
#          ],
#          "platform": null,
#          "self_reported_circulating_supply": null,
#          "self_reported_market_cap": null,
#          "quote": {
#             "USD": {
#                "price": 0.6893559058856573,
#                "volume_24h": 1603,
#                "volume_change_24h": 0.374372336391531,
#                "percent_change_1h": 0.8067434692447815,
#                "percent_change_24h": 0.5891273056643371,
#                "percent_change_7d": 0.00992934166634818,
#                "market_cap": 0.37107548613347063,
#                "market_cap_dominance": 7991,
#                "fully_diluted_market_cap": 0.5109006243982575,
#                "last_updated": "2022-05-11T01:08:35.562Z"
#             }
#          }
#       }
#    ]
# }
